# %%
import pandas as pd
import numpy as np

# Importing High yield corporate bonds dataset using pandas
df = pd.read_csv("HY_Universe_corporate bond.csv")

df.head()
# Out:
#        CUSIP  Ticker  Issue Date    Maturity 1st Call Date Moodys S_and_P  \
# 0  000324AA1  FLECIN    7/1/2014    7/1/2019    10/23/2017    Nan     Nan
# 1  00080QAB1     RBS   3/15/2004    6/4/2018           Nan    Ba1     BB+
# 2  00081TAD0    ACCO   5/14/2010   3/15/2015           Nan     WR      NR
# 3  00081TAH1    ACCO   6/17/2013   4/30/2020           Nan     WR      NR
# 4  00081TAJ7    ACCO  12/22/2016  12/15/2024    12/15/2019     B1     BB-
#
#   Fitch Bloomberg Composite Rating  Coupon  ...  percent_intra_dealer  \
# 0   Nan                        Nan   12.00  ...              0.006645
# 1   BBB                        BB+    4.65  ...              0.425018
# 2   BB+                         NR   10.63  ...              0.115207
# 3    WD                         NR    6.75  ...              0.426332
# 4    BB                        BB-    5.25  ...              0.157216
#
#   percent_uncapped bond_type  Client_Trade_Percentage weekly_mean_volume  \
# ...

# %%
df.shape
# Out:
# (2721, 37)

# %%
df.dtypes
# Out:
# CUSIP                          object
# Ticker                         object
# Issue Date                     object
# Maturity                       object
# 1st Call Date                  object
# Moodys                         object
# S_and_P                        object
# Fitch                          object
# Bloomberg Composite Rating     object
# Coupon                        float64
# Issued Amount                 float64
# Maturity Type                  object
# Coupon Type                    object
# Maturity At Issue months      float64
# Industry                       object
# LiquidityScore                float64
# Months in JNK                  object
# Months in HYG                  object
# Months in Both                 object
# IN_ETF                         object
# LIQ SCORE                     float64
# n_trades                        int64
# volume_trades                 float64
# total_median_size             float64
# total_mean_size               float64
# ...

# %%
# Summary Statistics of the entire dataset
df.describe()
# Out:
#             Coupon  Issued Amount  Maturity At Issue months  LiquidityScore  \
# count  2721.000000   2.721000e+03               2721.000000     2721.000000
# mean     10.307872   8.299295e+08                113.968997       18.218230
# std      63.051382   5.802790e+08                101.893176        7.872071
# min       0.000000   3.700000e+08                 11.930000        4.388758
# 25%       5.000000   5.000000e+08                 65.170000       12.738630
# 50%       6.250000   6.500000e+08                 97.370000       16.538471
# 75%       7.750000   1.000000e+09                121.770000       22.120108
# max     999.000000   7.364026e+09               1217.570000       54.673908
#
#          LIQ SCORE      n_trades  volume_trades  total_median_size  \
# count  2721.000000   2721.000000   2.721000e+03       2.721000e+03
# mean      0.182182   2700.696435   7.222372e+08       5.361476e+05
# std       0.078721   5572.262205   1.027825e+09       4.193546e+05
# ...

# %%
# Including variables to do EDA
X=df[['Coupon','LiquidityScore','n_trades','volume_trades',
             'total_median_size','total_mean_size','n_days_trade',
             'days_diff_max','percent_intra_dealer','percent_uncapped',
            'Client_Trade_Percentage','weekly_mean_volume',
            'weekly_median_volume','weekly_max_volume','weekly_min_volume',
            'weekly_mean_ntrades','weekly_median_ntrades']]
y=df[['Industry','IN_ETF','bond_type']]

# %%
X.head()
# Out:
#    Coupon  LiquidityScore  n_trades  volume_trades  total_median_size  \
# 0   12.00       10.891365       301   2.640038e+08          1000000.0
# 1    4.65       24.625486      2854   2.668630e+08            24000.0
# 2   10.63       12.841557       434   2.814210e+08           875000.0
# 3    6.75       26.226355      4975   1.163167e+09            26000.0
# 4    5.25       14.138395       388   2.493420e+08           750000.0
#
#    total_mean_size  n_days_trade  days_diff_max  percent_intra_dealer  \
# 0      877088.9535           128           1132              0.006645
# 1       93504.9054           614           1041              0.425018
# 2      648435.4839           183            439              0.115207
# 3      233802.4121           773           1227              0.426332
# 4      642634.0206           126            246              0.157216
#
#    percent_uncapped  Client_Trade_Percentage  weekly_mean_volume  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Scaling the data
scaler = StandardScaler()
scaler.fit(X)
X_std  = scaler.transform(X)
X_std  = pd.DataFrame(X_std,columns = X.columns)

# %%
X_std.head()
# Out:
#      Coupon  LiquidityScore  n_trades  volume_trades  total_median_size  \
# 0  0.026842       -0.930913 -0.430729      -0.445910           1.106313
# 1 -0.089751        0.814072  0.027517      -0.443128          -1.221500
# 2  0.005110       -0.683132 -0.406857      -0.428961           0.808182
# 3 -0.056439        1.017470  0.408222       0.429072          -1.216730
# 4 -0.080233       -0.518362 -0.415114      -0.460178           0.510050
#
#    total_mean_size  n_days_trade  days_diff_max  percent_intra_dealer  \
# 0         1.316401     -0.542309       0.694581             -1.562157
# 1        -1.618166      0.855292       0.539578              1.187823
# 2         0.460081     -0.384144      -0.485821             -0.848569
# 3        -1.092743      1.312532       0.856396              1.196461
# 4         0.438354     -0.548060      -0.814562             -0.572442
#
#    percent_uncapped  Client_Trade_Percentage  weekly_mean_volume  \
# ...

# %%
y.head()
# Out:
#                    Industry IN_ETF  bond_type
# 0               Real Estate     No          5
# 1                     Banks    Yes          2
# 2  Household Products/Wares     No          5
# 3  Household Products/Wares    Yes          3
# 4  Household Products/Wares     No          5

# %%
X_std.describe()
# Out:
#              Coupon  LiquidityScore      n_trades  volume_trades  \
# count  2.721000e+03    2.721000e+03  2.721000e+03   2.721000e+03
# mean  -2.343056e-17    2.148673e-16  1.055446e-16  -3.836155e-17
# std    1.000184e+00    1.000184e+00  1.000184e+00   1.000184e+00
# min   -1.635137e-01   -1.757100e+00 -4.845775e-01  -7.028074e-01
# 25%   -8.419875e-02   -6.962091e-01 -4.639357e-01  -6.425886e-01
# 50%   -6.437001e-02   -2.134212e-01 -3.637785e-01  -3.641729e-01
# 75%   -4.057551e-02    4.957520e-01 -4.194695e-02   2.049410e-01
# max    1.568362e+01    4.631866e+00  9.914188e+00   8.035649e+00
#
#        total_median_size  total_mean_size  n_days_trade  days_diff_max  \
# count       2.721000e+03     2.721000e+03  2.721000e+03   2.721000e+03
# mean        3.160117e-17     7.944154e-17  5.773486e-17  -1.629531e-18
# std         1.000184e+00     1.000184e+00  1.000184e+00   1.000184e+00
# min        -1.269202e+00    -1.949621e+00 -9.075256e-01  -1.233579e+00
# ...

# %%
X.describe()
# Out:
#             Coupon  LiquidityScore      n_trades  volume_trades  \
# count  2721.000000     2721.000000   2721.000000   2.721000e+03
# mean     10.307872       18.218230   2700.696435   7.222372e+08
# std      63.051382        7.872071   5572.262205   1.027825e+09
# min       0.000000        4.388758      1.000000   7.000000e+03
# 25%       5.000000       12.738630    116.000000   6.189000e+07
# 50%       6.250000       16.538471    674.000000   3.480000e+08
# 75%       7.750000       22.120108   2467.000000   9.328420e+08
# max     999.000000       54.673908  57935.000000   8.979960e+09
#
#        total_median_size  total_mean_size  n_days_trade  days_diff_max  \
# count       2.721000e+03     2.721000e+03   2721.000000    2721.000000
# mean        5.361476e+05     5.255853e+05    316.581771     724.219772
# std         4.193546e+05     2.670677e+05    347.802629     587.196329
# min         4.000000e+03     5.000000e+03      1.000000       0.000000
# ...

# %%
X_std.skew()
# Out:
# Coupon                     15.603691
# LiquidityScore              1.081479
# n_trades                    4.090840
# volume_trades               2.740594
# total_median_size           0.076760
# total_mean_size             0.354001
# n_days_trade                1.416918
# days_diff_max               0.774720
# percent_intra_dealer        0.068575
# percent_uncapped           -0.654189
# Client_Trade_Percentage     1.069550
# weekly_mean_volume          4.286502
# weekly_median_volume        5.590998
# weekly_max_volume           3.654629
# weekly_min_volume          18.456780
# weekly_mean_ntrades         4.358272
# weekly_median_ntrades      13.432663
# dtype: float64

# %%
# Boxplots to visualise outliers
import seaborn as  sns
import matplotlib.pyplot as plt

plt.figure(figsize=(16,20 ))
sns.boxplot(data = X_std,orient = 'h')

# %%
# Swarmplots 

sns.swarmplot(y = 'LiquidityScore', data = X_std)

# %%
sns.swarmplot(y = 'n_days_trade', data = X_std)

# %%
sns.swarmplot(y = 'total_median_size', data = X_std)

# %%
sns.swarmplot(y = 'Client_Trade_Percentage', data = X_std)

# %%
# pairwise scatter plots 

X_std.plot.scatter(x = 'LiquidityScore', y = 'weekly_median_ntrades', 
                   c = 'DarkBlue')

# %%
X_std.plot.scatter(x = 'LiquidityScore', y = 'n_trades', c = 'Green')

# %%
X_std.plot.scatter(x = 'LiquidityScore', y = 'Client_Trade_Percentage', 
                   c = 'Red')

# %%
X_std.plot.scatter(x = 'weekly_median_ntrades', y = 'Client_Trade_Percentage', 
                   c = 'Orange')

# %%
X_std.plot.scatter(x = 'percent_intra_dealer', y = 'weekly_median_volume', 
                   c = 'Purple')

# %%
# Correlation heat map to determine the variables we need to do analysis on
corr_mat = pd.DataFrame(X.corr())
plt.pcolor(corr_mat)

# %%
sns.set(font_scale = 1.2)
fig, ax = plt.subplots(figsize=(20,20)) 
heat_map = sns.heatmap(corr_mat,annot=True)

# %%
# Boxplots using bond_type and IN_ETF
sns.boxplot(x='bond_type', y='weekly_median_ntrades', data=df)

# %%
sns.boxplot(x='bond_type', y='percent_intra_dealer', data=df)

# %%
sns.boxplot(x='IN_ETF', y='weekly_median_ntrades', data=df)

# %%
sns.boxplot(x='IN_ETF', y='percent_intra_dealer', data=df)

# %%
# Histogram of bond_type

y.hist(column='bond_type')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B23D4C8748>]],
#       dtype=object)
